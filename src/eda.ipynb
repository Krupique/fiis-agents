# %% [markdown]
# # FIIs Agents

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = yf.Ticker("BTLG11.SA")

# %%
dividends = ticker.dividends
prices = ticker.history(period="6mo")

print('Dividends')
print(dividends)

print('Last Prices')
display(prices)
# Out:
# Dividends
# Date
# 2017-10-17 00:00:00-02:00    0.330043
# 2017-11-17 00:00:00-02:00    0.315382
# 2022-04-18 00:00:00-03:00    0.710581
# 2022-05-16 00:00:00-03:00    0.710581
# 2022-06-17 00:00:00-03:00    0.710581
# 2022-07-18 00:00:00-03:00    0.809272
# 2022-08-16 00:00:00-03:00    0.730319
# 2022-09-16 00:00:00-03:00    0.730319
# 2022-10-17 00:00:00-03:00    0.730319
# 2022-11-16 00:00:00-03:00    0.730319
# 2022-12-16 00:00:00-03:00    0.730319
# 2023-01-16 00:00:00-03:00    0.730319
# 2023-02-16 00:00:00-03:00    0.730319
# 2023-03-16 00:00:00-03:00    0.730319
# 2023-04-17 00:00:00-03:00    0.730319
# 2023-05-16 00:00:00-03:00    0.730319
# 2023-06-16 00:00:00-03:00    0.730319
# 2023-07-17 00:00:00-03:00    0.750057
# 2023-08-16 00:00:00-03:00    0.756380
# 2023-09-18 00:00:00-03:00    0.756380
# 2023-10-16 00:00:00-03:00    0.756380
# 2023-11-16 00:00:00-03:00    0.756380
# 2023-12-18 00:00:00-03:00    0.756380
# 2024-01-16 00:00:00-03:00    0.806142
# ...

# %%
prices["Close"].plot(title="BTLG11 - Price")
plt.show()
